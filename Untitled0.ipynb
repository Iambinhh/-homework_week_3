# %% [markdown]
# <a href="https://colab.research.google.com/github/Iambinhh/-homework_week_3/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url='http://winterolympicsmedals.com/medals.csv'
dataframe=pd.read_csv(url)

#dat
dataframe.groupby('NOC')['Medal'].count()
dataframe.groupby('Sport')['Medal'].count()

dataframe[(dataframe['Event']=='individual')&(dataframe['Sport']=='Skating')&(dataframe['Medal']=='Gold')]
dataframe[(dataframe['Event']=='individual')&(dataframe['Sport']=='Skating')&(dataframe['Medal']=='Silver')]
dataframe[(dataframe['Event']=='individual')&(dataframe['Sport']=='Skating')&(dataframe['Medal']=='Bronze')]



#tim so huy chuong cua mot nuoc nao do
#Tim so huy chuong vang, bac, dong theo mot mon thi nao do
# Out:
#       Year                    City    Sport      Discipline  NOC       Event  \
# 22    1924                Chamonix  Skating  Figure skating  GBR  individual
# 42    1924                Chamonix  Skating  Figure skating  SUI  individual
# 53    1928              St. Moritz  Skating  Figure skating  BEL  individual
# 88    1928              St. Moritz  Skating  Figure skating  USA  individual
# 93    1932             Lake Placid  Skating  Figure skating  CAN  individual
# 125   1932             Lake Placid  Skating  Figure skating  USA  individual
# 132   1936  Garmisch-Partenkirchen  Skating  Figure skating  AUT  individual
# 172   1936  Garmisch-Partenkirchen  Skating  Figure skating  SWE  individual
# 183   1948              St. Moritz  Skating  Figure skating  AUT  individual
# 208   1948              St. Moritz  Skating  Figure skating  GBR  individual
# 270   1952                    Oslo  Skating  Figure skating  FRA  individual
# ...
